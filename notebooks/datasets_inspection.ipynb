# %% [markdown]
# # Imports

# %%
import pandas as pd

# %% [markdown]
# # Constants

# %%
HAO_DATASET = "../data/hao.csv"
KOTLIAROV_DATASET = "../data/kotliarov.csv"

# %% [markdown]
# # Datasets

# %% [markdown]
# What we have:
#
# - Rows: Cell barcodes (e.g. AAACCTGAGAGCCCAA_H1B1ln1)
# - Columns: Genes — z-scored expression levels
# - 168 columns → includes all 167 signature genes and a label column at the end

# %% [markdown]
# ## Reference

# %%
df_hao = pd.read_csv(HAO_DATASET, index_col=0)
df_hao.shape
# Out:
# (151533, 168)

# %%
df_hao.head()
# Out:
#                        MMP23B  TNFRSF25       CDA     CNR2       FGR  \
# L1_AAACCCAAGAAACTCA -0.195712 -0.381509  0.817605 -0.16203  0.140189
# L1_AAACCCAAGACATACA -0.195712  3.635496 -0.501826 -0.16203 -0.800555
# L1_AAACCCACAACTGGTT -0.195712 -0.381509 -0.501826 -0.16203 -0.800555
# L1_AAACCCACACGTACTA -0.195712 -0.381509 -0.501826 -0.16203 -0.800555
# L1_AAACCCACAGCATACT -0.195712 -0.381509 -0.501826 -0.16203 -0.800555
#
#                        TTC39A     CD160    S100A9   S100A12    S100A8  ...  \
# L1_AAACCCAAGAAACTCA -0.047442 -0.248082  1.205759  0.376751  0.426672  ...
# L1_AAACCCAAGACATACA -0.047442 -0.248082 -1.093067 -0.615584 -0.894601  ...
# L1_AAACCCACAACTGGTT -0.047442 -0.248082 -1.093067 -0.615584 -0.297802  ...
# L1_AAACCCACACGTACTA -0.047442  4.358360 -1.093067 -0.615584 -0.894601  ...
# L1_AAACCCACAGCATACT -0.047442 -0.248082 -1.093067 -0.615584 -0.894601  ...
#
#                       KIR2DL4    IGLL5    VPREB3     DERL3      XBP1  \
# L1_AAACCCAAGAAACTCA -0.071031 -0.07138 -0.252574 -0.139402  0.151826
# L1_AAACCCAAGACATACA -0.071031 -0.07138 -0.252574 -0.139402 -0.871874
# L1_AAACCCACAACTGGTT -0.071031 -0.07138 -0.252574 -0.139402 -0.871874
# L1_AAACCCACACGTACTA -0.071031 -0.07138 -0.252574 -0.139402  0.892713
# L1_AAACCCACAGCATACT -0.071031 -0.07138 -0.252574 -0.139402 -0.871874
#
#                      APOBEC3A  APOBEC3G  TNFRSF13C     S100B  label
# L1_AAACCCAAGAAACTCA  0.533528 -0.628123  -0.305063 -0.201506   Mono
# L1_AAACCCAAGACATACA -0.479485 -0.628123  -0.305063 -0.201506  T CD4
# L1_AAACCCACAACTGGTT -0.479485 -0.628123  -0.305063 -0.201506  T CD8
# L1_AAACCCACACGTACTA -0.479485  3.266895  -0.305063 -0.201506     NK
# L1_AAACCCACAGCATACT -0.479485 -0.628123  -0.305063 -0.201506  T CD8
#
# [5 rows x 168 columns]

# %%
df_hao.columns[-5:]
# Out:
# Index(['APOBEC3A', 'APOBEC3G', 'TNFRSF13C', 'S100B', 'label'], dtype='object')

# %% [markdown]
# ## Validation

# %%
df_kotliarov = pd.read_csv(KOTLIAROV_DATASET, index_col=0)
df_kotliarov.shape
# Out:
# (52849, 168)

# %%
df_kotliarov.head()
# Out:
#                             MMP23B  TNFRSF25       CDA      CNR2       FGR  \
# AAACCTGAGAGCCCAA_H1B1ln1 -0.116767 -0.293528 -0.225603 -0.102697 -0.388332
# AAACCTGAGGCGTACA_H1B1ln1 -0.116767 -0.293528 -0.225603 -0.102697 -0.388332
# AAACCTGCAGGTGGAT_H1B1ln1 -0.116767 -0.293528 -0.225603 -0.102697 -0.388332
# AAACCTGCAGTATCTG_H1B1ln1 -0.116767 -0.293528 -0.225603 -0.102697 -0.388332
# AAACCTGCATCACAAC_H1B1ln1 -0.116767 -0.293528 -0.225603 -0.102697 -0.388332
#
#                             TTC39A     CD160    S100A9   S100A12    S100A8  \
# AAACCTGAGAGCCCAA_H1B1ln1 -0.023106 -0.182332 -0.721293 -0.375674  0.797596
# AAACCTGAGGCGTACA_H1B1ln1 -0.023106 -0.182332 -0.721293 -0.375674 -0.710046
# AAACCTGCAGGTGGAT_H1B1ln1 -0.023106 -0.182332 -0.721293 -0.375674 -0.710046
# AAACCTGCAGTATCTG_H1B1ln1 -0.023106 -0.182332 -0.721293 -0.375674 -0.710046
# AAACCTGCATCACAAC_H1B1ln1 -0.023106 -0.182332  1.691482  2.895297  1.783545
#
#                           ...   KIR2DL4     IGLL5   VPREB3     DERL3  \
# AAACCTGAGAGCCCAA_H1B1ln1  ... -0.012269 -0.344302 -0.20142 -0.102709
# AAACCTGAGGCGTACA_H1B1ln1  ... -0.012269 -0.344302 -0.20142 -0.102709
# AAACCTGCAGGTGGAT_H1B1ln1  ... -0.012269 -0.344302 -0.20142 -0.102709
# AAACCTGCAGTATCTG_H1B1ln1  ... -0.012269 -0.344302 -0.20142 -0.102709
# AAACCTGCATCACAAC_H1B1ln1  ... -0.012269 -0.344302 -0.20142 -0.102709
#
#                               XBP1  APOBEC3A  APOBEC3G  TNFRSF13C     S100B  \
# AAACCTGAGAGCCCAA_H1B1ln1  1.561382 -0.200098   -0.3262  -0.116761 -0.192388
# AAACCTGAGGCGTACA_H1B1ln1 -0.497692 -0.200098   -0.3262  -0.116761 -0.192388
# AAACCTGCAGGTGGAT_H1B1ln1 -0.497692 -0.200098   -0.3262  -0.116761 -0.192388
# AAACCTGCAGTATCTG_H1B1ln1 -0.497692 -0.200098   -0.3262  -0.116761 -0.192388
# AAACCTGCATCACAAC_H1B1ln1  1.207505 -0.200098   -0.3262  -0.116761 -0.192388
#
#                           label
# AAACCTGAGAGCCCAA_H1B1ln1     NK
# AAACCTGAGGCGTACA_H1B1ln1  T CD8
# AAACCTGCAGGTGGAT_H1B1ln1  T CD4
# AAACCTGCAGTATCTG_H1B1ln1  T CD4
# AAACCTGCATCACAAC_H1B1ln1   Mono
#
# [5 rows x 168 columns]

# %%
df_kotliarov.columns[-5:]
# Out:
# Index(['APOBEC3A', 'APOBEC3G', 'TNFRSF13C', 'S100B', 'label'], dtype='object')
